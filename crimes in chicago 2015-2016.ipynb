# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
crimes=pd.read_csv("/home/user/Downloads/Crimes-in-chicago-master/Chicago_Crimes_2012_to_2017.csv")
crimes.head()
# Out:
#    Unnamed: 0        ID Case Number                    Date  \
# 0           3  10508693    HZ250496  05/03/2016 11:40:00 PM
# 1          89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2         197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3         673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4         911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description  \
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description  Arrest              ...                Ward  \
# 0            APARTMENT    True              ...                24.0
# 1            RESIDENCE   False              ...                20.0
# 2               STREET   False              ...                37.0
# 3             SIDEWALK   False              ...                28.0
# 4            RESIDENCE   False              ...                28.0
#
#    Community Area  FBI Code  X Coordinate  Y Coordinate  Year  \
# 0            29.0       08B     1154907.0     1893681.0  2016
# 1            42.0       08B     1183066.0     1864330.0  2016
# 2            25.0        24     1140789.0     1904819.0  2016
# 3            25.0       08B     1143223.0     1901475.0  2016
# 4            25.0        06     1139890.0     1901675.0  2016
#
#                Updated On   Latitude  Longitude                       Location
# 0  05/10/2016 03:56:50 PM  41.864073 -87.706819  (41.864073157, -87.706818608)
# 1  05/10/2016 03:56:50 PM  41.782922 -87.604363   (41.782921527, -87.60436317)
# 2  05/10/2016 03:56:50 PM  41.894908 -87.758372  (41.894908283, -87.758371958)
# 3  05/10/2016 03:56:50 PM  41.885687 -87.749516  (41.885686845, -87.749515983)
# 4  05/10/2016 03:56:50 PM  41.886297 -87.761751  (41.886297242, -87.761750709)
#
# [5 rows x 23 columns]

# %%
crimes.describe()
# Out:
#          Unnamed: 0            ID          Beat      District          Ward  \
# count  1.456714e+06  1.456714e+06  1.456714e+06  1.456713e+06  1.456700e+06
# mean   3.308606e+06  9.597550e+06  1.150644e+03  1.125920e+01  2.287027e+01
# std    1.235350e+06  8.083505e+05  6.916466e+02  6.904691e+00  1.380589e+01
# min    3.000000e+00  2.022400e+04  1.110000e+02  1.000000e+00  1.000000e+00
# 25%    2.698636e+06  9.002709e+06  6.130000e+02  6.000000e+00  1.000000e+01
# 50%    3.063654e+06  9.605776e+06  1.024000e+03  1.000000e+01  2.300000e+01
# 75%    3.428849e+06  1.022577e+07  1.711000e+03  1.700000e+01  3.400000e+01
# max    6.253474e+06  1.082788e+07  2.535000e+03  3.100000e+01  5.000000e+01
#
#        Community Area  X Coordinate  Y Coordinate          Year      Latitude  \
# count    1.456674e+06  1.419631e+06  1.419631e+06  1.456714e+06  1.419631e+06
# mean     3.745632e+01  1.164398e+06  1.885523e+06  2.013897e+03  4.184147e+01
# std      2.144029e+01  1.850835e+04  3.424775e+04  1.449584e+00  9.430126e-02
# min      0.000000e+00  0.000000e+00  0.000000e+00  2.012000e+03  3.661945e+01
# 25%      2.300000e+01  1.152544e+06  1.858762e+06  2.013000e+03  4.176787e+01
# 50%      3.200000e+01  1.166021e+06  1.891502e+06  2.014000e+03  4.185797e+01
# 75%      5.600000e+01  1.176363e+06  1.908713e+06  2.015000e+03  4.190529e+01
# max      7.700000e+01  1.205119e+06  1.951573e+06  2.017000e+03  4.202271e+01
#
#           Longitude
# count  1.419631e+06
# mean  -8.767224e+01
# std    6.661726e-02
# min   -9.168657e+01
# 25%   -8.771528e+01
# 50%   -8.766613e+01
# 75%   -8.762813e+01
# max   -8.752453e+01

# %%
crimes.drop(['Unnamed: 0', 'Case Number','Block','IUCR', 'X Coordinate', 'Y Coordinate', 'FBI Code', 'Beat','Ward','Community Area', 'Location','Latitude','Longitude','District'], inplace=True, axis=1)
crimes.head(4)
# Out:
#          ID                    Date            Primary Type  \
# 0  10508693  05/03/2016 11:40:00 PM                 BATTERY
# 1  10508695  05/03/2016 09:40:00 PM                 BATTERY
# 2  10508697  05/03/2016 11:31:00 PM  PUBLIC PEACE VIOLATION
# 3  10508698  05/03/2016 10:10:00 PM                 BATTERY
#
#                Description Location Description  Arrest  Domestic  Year  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  2016
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True  2016
# 2         RECKLESS CONDUCT               STREET   False     False  2016
# 3                   SIMPLE             SIDEWALK   False     False  2016
#
#                Updated On
# 0  05/10/2016 03:56:50 PM
# 1  05/10/2016 03:56:50 PM
# 2  05/10/2016 03:56:50 PM
# 3  05/10/2016 03:56:50 PM

# %%
crimes=crimes[(crimes['Year']==2016)|(crimes['Year']==2015)]
crimes.describe()
# Out:
#                  ID           Year
# count  5.284570e+05  528457.000000
# mean   1.034563e+07    2015.502334
# std    5.663949e+05       0.499995
# min    2.171400e+04    2015.000000
# 25%    1.014746e+07    2015.000000
# 50%    1.037163e+07    2016.000000
# 75%    1.059204e+07    2016.000000
# max    1.082787e+07    2016.000000

# %% [markdown]
# # Crimes each year

# %%
sns.countplot(x='Year',data=crimes)
plt.ylabel('No of Crimes')
plt.show()

# %%
crimes['Date'] = pd.to_datetime(crimes['Date'],format='%m/%d/%Y %I:%M:%S %p')

# %%
import calendar
crimes['Month']=(crimes['Date'].dt.month).apply(lambda x: calendar.month_abbr[x])
crimes.head(4)
# Out:
#          ID                Date            Primary Type  \
# 0  10508693 2016-05-03 23:40:00                 BATTERY
# 1  10508695 2016-05-03 21:40:00                 BATTERY
# 2  10508697 2016-05-03 23:31:00  PUBLIC PEACE VIOLATION
# 3  10508698 2016-05-03 22:10:00                 BATTERY
#
#                Description Location Description  Arrest  Domestic  Year  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  2016
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True  2016
# 2         RECKLESS CONDUCT               STREET   False     False  2016
# 3                   SIMPLE             SIDEWALK   False     False  2016
#
#                Updated On Month
# 0  05/10/2016 03:56:50 PM   May
# 1  05/10/2016 03:56:50 PM   May
# 2  05/10/2016 03:56:50 PM   May
# 3  05/10/2016 03:56:50 PM   May

# %%
crimes['Month'] = pd.Categorical(crimes['Month'] , categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'], ordered=True)

# %% [markdown]
# # Crimes per month

# %%
import numpy as np
months=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']
crimes.groupby('Month')['ID'].count().plot(marker='o')
plt.xticks(np.arange(12),months)
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Comparison  of crimes per month in each year

# %%
crimes.groupby(['Month','Year'])['ID'].count().unstack().plot(kind='bar')
plt.ylabel('No of crimes')
plt.show()

# %%
crimes["Weekday"] = crimes['Date'].dt.weekday_name
crimes['Weekday'] = pd.Categorical(crimes['Weekday'],categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday', 'Sunday'], ordered=True)
crimes.head()
# Out:
#          ID                Date            Primary Type  \
# 0  10508693 2016-05-03 23:40:00                 BATTERY
# 1  10508695 2016-05-03 21:40:00                 BATTERY
# 2  10508697 2016-05-03 23:31:00  PUBLIC PEACE VIOLATION
# 3  10508698 2016-05-03 22:10:00                 BATTERY
# 4  10508699 2016-05-03 22:00:00                   THEFT
#
#                Description Location Description  Arrest  Domestic  Year  \
# 0  DOMESTIC BATTERY SIMPLE            APARTMENT    True      True  2016
# 1  DOMESTIC BATTERY SIMPLE            RESIDENCE   False      True  2016
# 2         RECKLESS CONDUCT               STREET   False     False  2016
# 3                   SIMPLE             SIDEWALK   False     False  2016
# 4           $500 AND UNDER            RESIDENCE   False      True  2016
#
#                Updated On Month  Weekday
# 0  05/10/2016 03:56:50 PM   May  Tuesday
# 1  05/10/2016 03:56:50 PM   May  Tuesday
# 2  05/10/2016 03:56:50 PM   May  Tuesday
# 3  05/10/2016 03:56:50 PM   May  Tuesday
# 4  05/10/2016 03:56:50 PM   May  Tuesday

# %% [markdown]
# # No of crimes recorded on days of the week

# %%
crimes.groupby('Weekday')['ID'].count().plot(marker='o',label='Crimes')
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Types of Crime in chicago

# %%
sns.countplot(x='Primary Type',data=crimes,order=crimes['Primary Type'].value_counts().index)
plt.xticks(rotation='vertical')
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Top 10 Location where crime occurs

# %%
temp=crimes.groupby('Location Description')['ID'].count().sort_values(ascending=False)
temp=temp[:10]
temp
# Out:
# Location Description
# STREET                            121632
# RESIDENCE                          85754
# APARTMENT                          68607
# SIDEWALK                           51134
# OTHER                              21552
# PARKING LOT/GARAGE(NON.RESID.)     15538
# SMALL RETAIL STORE                 11322
# RESIDENTIAL YARD (FRONT/BACK)      11059
# ALLEY                              10877
# RESTAURANT                         10635
# Name: ID, dtype: int64

# %%
temp.plot(kind='bar',color='green')
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Was the criminal arrested?

# %%
sns.countplot(x='Arrest',data=crimes)
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Year-wise Arrests

# %%
crimes.groupby(['Year','Arrest'])['ID'].count().unstack().plot(kind='bar')
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Crime-Wise arrests

# %%
sns.set(rc={'figure.figsize':(12,6)})
sns.countplot(x='Primary Type',hue='Arrest',data=crimes,order=crimes['Primary Type'].value_counts().index)
plt.xticks(rotation='vertical')
plt.ylabel('No of Crimes')
plt.show()

# %%
arrest=crimes[crimes['Arrest']==True]
arrest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119783 entries, 0 to 1456713
# Data columns (total 11 columns):
# ID                      119783 non-null int64
# Date                    119783 non-null datetime64[ns]
# Primary Type            119783 non-null object
# Description             119783 non-null object
# Location Description    119781 non-null object
# Arrest                  119783 non-null bool
# Domestic                119783 non-null bool
# Year                    119783 non-null int64
# Updated On              119783 non-null object
# Month                   119783 non-null category
# Weekday                 119783 non-null category
# dtypes: bool(2), category(2), datetime64[ns](1), int64(2), object(4)
# memory usage: 7.8+ MB

# %% [markdown]
# # Crime vs Arrest

# %%
arrest.groupby('Month')['ID'].count().plot(legend=True,label='Arrests',marker='o',figsize=(8,6))
crimes.groupby('Month')['ID'].count().plot(legend=True,label='Crimes',marker='o')
plt.ylabel('No of Crimes')
plt.xticks(np.arange(12),months)
plt.show()

# %%
crimes.groupby('Month')['ID'].count()
# Out:
# Month
# Jan    41031
# Feb    34877
# Mar    43438
# Apr    42572
# May    46902
# Jun    46850
# Jul    48747
# Aug    49304
# Sep    46231
# Oct    46293
# Nov    41626
# Dec    40586
# Name: ID, dtype: int64

# %%
arrest.groupby('Month')['ID'].count()
# Out:
# Month
# Jan    10303
# Feb     9273
# Mar    11383
# Apr    10770
# May    11327
# Jun    10742
# Jul    10695
# Aug    10173
# Sep     9690
# Oct     9645
# Nov     8434
# Dec     7348
# Name: ID, dtype: int64

# %% [markdown]
# # Analysing top 5 crimes

# %%
top_crime=crimes[(crimes['Primary Type']=='THEFT')|(crimes['Primary Type']=='BATTERY')|(crimes['Primary Type']=='CRIMINAL DAMAGE')|(crimes['Primary Type']=='NARCOTICS')|(crimes['Primary Type']=='ASSAULT')]

# %%
temp=top_crime.pivot_table(values='ID', index='Month', columns='Year', aggfunc=np.size)

# %%
temp
# Out:
# Year    2015   2016
# Month
# Jan    13404  12934
# Feb    10686  12110
# Mar    14529  14567
# Apr    14582  13939
# May    16073  15638
# Jun    15475  15849
# Jul    16300  16408
# Aug    16611  16086
# Sep    15524  15263
# Oct    15300  15055
# Nov    13529  13570
# Dec    13725  12092

# %%
sns.heatmap(temp)
plt.show()

# %%
top_crime.groupby(['Month','Year'])['ID'].count().unstack().plot(marker='o')
plt.xticks(np.arange(12),months)
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Hour of crime

# %%
temp= top_crime.pivot_table(values='ID', index='Primary Type',columns=top_crime['Date'].dt.hour, aggfunc=np.size)
sns.heatmap(temp)
plt.xlabel('Hours of the day')
plt.ylabel('Type of Crime')
plt.show()

# %%
top_crime.groupby([top_crime['Date'].dt.hour,'Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.xlabel('Hours of the day')
plt.xticks(np.arange(24))
plt.show()

# %% [markdown]
# # Monthly trend in top 5 crimes

# %%
temp= top_crime.pivot_table(values='ID', index='Primary Type', columns='Month', aggfunc=np.size)
temp
# Out:
# Month             Jan   Feb   Mar   Apr   May    Jun    Jul    Aug    Sep  \
# Primary Type
# ASSAULT          2447  2322  3076  2904  3462   3405   3304   3351   3221
# BATTERY          7263  6408  8408  8142  9602   9419   9258   9210   8579
# CRIMINAL DAMAGE  4295  3591  4776  4854  5330   5103   5807   5657   5360
# NARCOTICS        3462  3255  3918  3520  3347   3058   3142   2885   2744
# THEFT            8871  7220  8918  9101  9970  10339  11197  11594  10883
#
# Month              Oct   Nov   Dec
# Primary Type
# ASSAULT           3087  2669  2502
# BATTERY           8371  7368  7119
# CRIMINAL DAMAGE   5348  4962  4564
# NARCOTICS         2723  2355  1837
# THEFT            10826  9745  9795

# %%
sns.heatmap(temp)
plt.ylabel('Type of Crime')
plt.show()

# %%
top_crime.groupby(['Month','Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.xticks(np.arange(12),months)
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Weekly trend in top 5 crime

# %%
temp= top_crime.pivot_table(values='ID', index='Primary Type', columns='Weekday', aggfunc=np.size)
temp
# Out:
# Weekday          Monday  Tuesday  Wednesday  Thursday  Friday  Saturday  \
# Primary Type
# ASSAULT            5142     5329       5248      5154    5076      4904
# BATTERY           13653    12896      12801     13230   13758     15882
# CRIMINAL DAMAGE    8157     7705       7910      8131    8845      9717
# NARCOTICS          4837     5227       5340      5655    5940      4696
# THEFT             16843    16674      16883     17168   18223     17116
#
# Weekday          Sunday
# Primary Type
# ASSAULT            4897
# BATTERY           16927
# CRIMINAL DAMAGE    9182
# NARCOTICS          4551
# THEFT             15552

# %%
sns.heatmap(temp)
plt.ylabel('Type of Crime')
plt.show()

# %%
top_crime.groupby(['Weekday','Primary Type',])['ID'].count().unstack().plot(marker='o')
plt.ylabel('No of Crimes')
plt.show()

# %% [markdown]
# # Location description for top 5 crimes

# %%
temp=list(top_crime['Location Description'].value_counts()[:20].index)
top_crime['Location Description']=np.where(top_crime['Location Description'].isin(temp),top_crime['Location Description'],'OTHER')
# Out:
# /home/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
top_crime['Location Description'].value_counts()
# Out:
# STREET                            83162
# APARTMENT                         46057
# RESIDENCE                         45688
# OTHER                             45229
# SIDEWALK                          36800
# PARKING LOT/GARAGE(NON.RESID.)    11829
# RESIDENTIAL YARD (FRONT/BACK)      8406
# SMALL RETAIL STORE                 8299
# RESIDENCE PORCH/HALLWAY            7643
# VEHICLE NON-COMMERCIAL             7354
# ALLEY                              7246
# RESTAURANT                         7173
# DEPARTMENT STORE                   6998
# SCHOOL, PUBLIC, BUILDING           6546
# GROCERY FOOD STORE                 5025
# RESIDENCE-GARAGE                   4277
# GAS STATION                        3444
# PARK PROPERTY                      3240
# BAR OR TAVERN                      2888
# CONVENIENCE STORE                  1945
# Name: Location Description, dtype: int64

# %%
temp= top_crime.pivot_table(values='ID', index='Location Description', columns='Primary Type', aggfunc=np.size)
temp
# Out:
# Primary Type                    ASSAULT  BATTERY  CRIMINAL DAMAGE  NARCOTICS  \
# Location Description
# ALLEY                               877     2068              980       2286
# APARTMENT                          5327    24264             7719       1332
# BAR OR TAVERN                       110      974              140         21
# CONVENIENCE STORE                   267      292              175         53
# DEPARTMENT STORE                    173      165               79         18
# GAS STATION                         475      644              387        494
# GROCERY FOOD STORE                  309      369              162         37
# OTHER                              4686     9576             6143       3171
# PARK PROPERTY                       267      906              252        489
# PARKING LOT/GARAGE(NON.RESID.)      790     1663             2768       1167
# RESIDENCE                          5553    19217            10437       1463
# RESIDENCE PORCH/HALLWAY            1286     2231              831        526
# RESIDENCE-GARAGE                     73      173             2582         53
# RESIDENTIAL YARD (FRONT/BACK)       970     1708             1797        693
# RESTAURANT                          804     1062              719        109
# SCHOOL, PUBLIC, BUILDING           1392     2762              354        541
# SIDEWALK                           4949    15679              594      10767
# SMALL RETAIL STORE                  615      555              544         83
# STREET                             6645    13484            21910      11232
# VEHICLE NON-COMMERCIAL              182     1355             1074       1711
#
# Primary Type                    THEFT
# Location Description
# ALLEY                            1035
# APARTMENT                        7415
# BAR OR TAVERN                    1643
# CONVENIENCE STORE                1158
# DEPARTMENT STORE                 6563
# GAS STATION                      1444
# GROCERY FOOD STORE               4148
# OTHER                           21653
# PARK PROPERTY                    1326
# PARKING LOT/GARAGE(NON.RESID.)   5441
# RESIDENCE                        9018
# RESIDENCE PORCH/HALLWAY          2769
# RESIDENCE-GARAGE                 1396
# RESIDENTIAL YARD (FRONT/BACK)    3238
# RESTAURANT                       4479
# SCHOOL, PUBLIC, BUILDING         1497
# SIDEWALK                         4811
# SMALL RETAIL STORE               6502
# STREET                          29891
# VEHICLE NON-COMMERCIAL           3032

# %%
sns.heatmap(temp)
plt.show()
